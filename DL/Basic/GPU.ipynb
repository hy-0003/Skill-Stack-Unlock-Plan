# %%
# !nvidia-smi
# Out:
# Fri Apr 10 16:33:52 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.83                 Driver Version: 581.83         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   47C    P8              5W /   93W |     137MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
import torch.nn as nn


torch.device("cpu"), torch.device("cuda"), torch.device("cuda:1")
# Out:
# (device(type='cpu'), device(type='cuda'), device(type='cuda', index=1))

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
def try_gpu(i=0):
    if torch.cuda.device_count() >= i+1:
        return torch.device(f'cuda:{i}')
    return torch.device('cpu')


def try_all_gpu():
    devices = [torch.device(f'cuda:{i}') for i in range(torch.cuda.device_count())]
    return devices if devices else [torch.device('cpu')]


try_gpu(), try_gpu(10), try_all_gpu()
# Out:
# (device(type='cuda', index=0),
#  device(type='cpu'),
#  [device(type='cuda', index=0)])

# %%
x = torch.tensor([2.0,2,0])
print(x.device)


device = torch.device("cuda") if torch.device("cuda") else torch.device("cpu")
y = torch.tensor([2,2,0], device=device)
print(y.device)
# Out:
# cpu
# cuda:0

# %%
x = x.cuda(0)
x + y
# Out:
# tensor([4., 4., 0.], device='cuda:0')

# %%
Net = nn.Sequential(nn.Linear(3,6), nn.ReLU(), nn.Linear(6,2))
# Net(x)
Net = Net.to(device=device)
Net(x)
# Out:
# tensor([ 0.7635, -0.3923], device='cuda:0', grad_fn=<ViewBackward0>)

# %% [markdown]
# NN 必须与数据/输入在同一个设备才可以运行
